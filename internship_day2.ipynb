# %%
#List

name = ["suba", "aarthi", "rakshu"]
name.append("theerthika")

marks = [98, 78, 80]

print(name)
print(marks[1])

print(len(name))
print(len(marks))
# Out:
# ['suba', 'aarthi', 'rakshu', 'theerthika']
# 78
# 4
# 3

# %%
 #Tuple

days = ("Monday", "Tuesday", "Wednesday", "Thrusday","Friday" ,"Saturday","sunday")
print(days[6])
# Out:
# sunday

# %%
# Dictionary

student = {
    "name": "aarthi",
    "age": 21
}
