# %%
import pandas as pd
df=pd.read_csv("food_delivery_data.csv")
df.head(8)
# Out:
#    OrderID   OrderDate OrderTime     Location              FoodItem  Quantity  \
# 0        1  24-11-2025     03:01      Madurai  Paneer Butter Masala         3
# 1        2  13-12-2025     23:57      Madurai                 Pasta         1
# 2        3  22-04-2025     07:32  Tirunelveli              Sandwich         1
# 3        4  07-10-2025     13:14      Chennai               Noodles         5
# 4        5  24-12-2025     13:21      Madurai                  Idli         2
# 5        6  17-02-2025     12:06  Tirunelveli            Fried Rice         3
# 6        7  24-08-2025     17:07        Salem               Parotta         1
# 7        8  05-07-2025     18:12   Coimbatore  Paneer Butter Masala         1
#
#     Price  CustomerRating
# 0  182.85             3.3
# 1  328.01             3.1
# 2  315.72             4.4
# 3  196.84             4.7
# 4  170.43             4.5
# 5  333.56             4.6
# 6  311.86             4.7
# 7   99.25             3.5

# %%
df.tail(8)
# Out:
#      OrderID   OrderDate OrderTime     Location              FoodItem  \
# 992      993  13-05-2025     05:37      Chennai               Biryani
# 993      994  02-07-2025     05:03   Coimbatore                  Idli
# 994      995  25-01-2025     09:18      Chennai                 Pasta
# 995      996  18-02-2025     19:48  Tirunelveli                Burger
# 996      997  04-06-2025     08:43      Chennai  Paneer Butter Masala
# 997      998  07-01-2025     04:33      Chennai                  Idli
# 998      999  22-02-2025     06:09        Salem                 Pasta
# 999     1000  11-11-2025     22:53      Madurai                 Pasta
#
#      Quantity   Price  CustomerRating
# 992         2  214.27             4.8
# 993         3  256.20             4.8
# 994         1  295.82             4.5
# 995         5  215.49             3.6
# 996         3  120.25             4.2
# 997         3  407.10             3.8
# 998         2  429.26             4.6
# ...
