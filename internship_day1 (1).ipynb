# %%
name = "SUBAHARINI"
age = 19
CGPA = 9.5
placed = True

print("Student Name:", name)
print("Age:", age)
print("CGPA:", CGPA)
print("Placed:", placed)

print(type(name))
print(type(age))
print(type(CGPA))
print(type(placed))

print(len(name))
# Out:
# Student Name: SUBAHARINI
# Age: 19
# CGPA: 9.5
# Placed: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# 10
